# %%
 import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Dataset
data = {
    'RAM': [2, 3, 4, 6, 8],
    'Price': [10000, 15000, 20000, 30000, 40000]
}
df = pd.DataFrame(data)
# Features and target
X = df[['RAM']]
y = df['Price']
# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Train model
model = LinearRegression()
model.fit(X_train, y_train)
# Predict
pred = model.predict(X_test)
print("Predicted Mobile Price:", pred)
# Graph
plt.scatter(df['RAM'], df['Price'])
plt.plot(df['RAM'], model.predict(X), color='red')
plt.xlabel("RAM (GB)")
plt.ylabel("Mobile Price")
plt.title("Mobile Price Prediction")
plt.show()
# Out:
# Predicted Mobile Price: [20000.]
